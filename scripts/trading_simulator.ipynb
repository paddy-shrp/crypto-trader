# %%
import datetime as dt
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from data_center import DataCenter
from trading_simulator import Simulator
import time

stocks = ["ETH/USD"]

data_center = DataCenter(stocks, file_path="../data/data_center.csv")
trader_count = 100
starting_cash = 1000

start_date = dt.datetime(2023, 12, 1)
end_date = dt.datetime(2023, 12, 2)
step_time = dt.timedelta(minutes=15)

sim = Simulator(start_date, end_date, step_time, data_center, stocks, trader_count, starting_cash)

progbar = tf.keras.utils.Progbar(sim.get_steps_needed())

times = []
times.append(time.time())

while sim.current_date < sim.stop_date:
    progbar.update(int(np.floor(sim.get_simulation_progress() * sim.get_steps_needed())))
    sim.simualte()
    times.append(time.time())
progbar.update(int(sim.get_steps_needed()))

time_intervals = []
for i in range(2, len(times)):
    time_intervals.append((times[i] - times[i-1]) / trader_count)

trader_profits = []
trader_trade_counts = []
for trader in sim.traders:
    trader_profits.append(trader.get_net_worth() - starting_cash)
    trader_trade_counts.append(len(trader.trades))
x = np.arange(trader_count)
plt.scatter(x, trader_profits)
plt.scatter(x, trader_trade_counts)

# best_trader = sim.get_best_trader()
# x = np.arange(len(time_intervals))
# mean = round(np.mean(time_intervals), 4)
# title = str(round(best_trader.get_net_worth() - starting_cash, 2)) + " - " + str(mean)
# plt.title(title)
# plt.scatter(x, time_intervals, s=2)
# plt.axhline(mean)

plt.show()
# Out:
# Datacenter initalized!
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step
# Simulation initalized!
# 63/96 ━━━━━━━━━━━━━━━━━━━━ 12s 368ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 28
#      26 while sim.current_date < sim.stop_date:
#      27     progbar.update(int(np.floor(sim.get_simulation_progress() * sim.get_steps_needed())))
# ---> 28     sim.simualte()
#      29     times.append(time.time())
#      30 progbar.update(int(sim.get_steps_needed()))
#
# File ~/Documents/GitHub/crypto-trader/scripts/trading_simulator.py:42, in Simulator.simualte(self)
#      39 historical_data = np.flip(historical_data)[:900] / self.starting_cash
#      41 self.broker.update_timestamp(self.current_date)
# ---> 42 for trader in self.traders: trader.calculate_decisions(additional_trader_data.copy(), historical_data.copy())
#      43 self.add_time(self.step_time)
#
# File ~/Documents/GitHub/crypto-trader/scripts/objects/trader.py:67, in Trader.calculate_decisions(self, additional_trader_data, historical_data)
#      65 def calculate_decisions(self, additional_trader_data, historical_data):
#      66     for stock in self.portfolio:
# ---> 67         self.calculate_decision(stock, additional_trader_data, historical_data)
#
# File ~/Documents/GitHub/crypto-trader/scripts/objects/trader.py:56, in Trader.calculate_decision(self, stock, additional_trader_data, historical_data)
#      53     for _ in range(5): trader_data.append(0)
#      54 trader_data.extend(additional_trader_data)
# ---> 56 results = self.model.calculate(trader_data, historical_data)[0]
#      57 results = results / np.sum(results)
#      58 action = np.random.choice(range(len(results)), p=results)
#
# File ~/Documents/GitHub/crypto-trader/scripts/trader_nn.py:47, in TraderModel.calculate(self, trader_data, historical_data)
#      45 trader_data = tf.reshape(trader_data, (1, -1))
#      46 historical_data = tf.reshape(historical_data, (1, -1))
# ---> 47 return self([trader_data, historical_data]).numpy()
#
# File ~/Documents/GitHub/crypto-trader/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Documents/GitHub/crypto-trader/.venv/lib/python3.11/site-packages/keras/src/layers/layer.py:825, in Layer.__call__(self, *args, **kwargs)
#     823         outputs = super().__call__(*args, **kwargs)
#     824 else:
# --> 825     outputs = super().__call__(*args, **kwargs)
#     826 # Change the layout for the layer output if needed.
#     827 # This is useful for relayout intermediate tensor in the model
#     828 # to achieve the optimal performance.
#     829 distribution = distribution_lib.distribution()
#
# File ~/Documents/GitHub/crypto-trader/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Documents/GitHub/crypto-trader/.venv/lib/python3.11/site-packages/keras/src/ops/operation.py:48, in Operation.__call__(self, *args, **kwargs)
#      43             call_fn = self.call
#      44     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      45         call_fn,
#      46         object_name=(f"{self.__class__.__name__}.call()"),
#      47     )
# ---> 48     return call_fn(*args, **kwargs)
#      50 # Plain flow.
#      51 if any_symbolic_tensors(args, kwargs):
#
# File ~/Documents/GitHub/crypto-trader/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~/Documents/GitHub/crypto-trader/.venv/lib/python3.11/site-packages/keras/src/models/functional.py:195, in Functional.call(self, inputs, training, mask)
#     193         if mask is not None:
#     194             x._keras_mask = mask
# --> 195 outputs = self._run_through_graph(
#     196     inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     197 )
#     198 return unpack_singleton(outputs)
#
# File ~/Documents/GitHub/crypto-trader/.venv/lib/python3.11/site-packages/keras/src/ops/function.py:151, in Function._run_through_graph(self, inputs, operation_fn)
#     148     continue  # Node is not computable, try skipping.
#     150 args, kwargs = node.arguments.fill_in(tensor_dict)
# --> 151 outputs = operation_fn(node.operation)(*args, **kwargs)
#     153 # Update tensor_dict.
#     154 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# File ~/Documents/GitHub/crypto-trader/.venv/lib/python3.11/site-packages/keras/src/models/functional.py:579, in operation_fn.<locals>.call(*args, **kwargs)
#     573 if (
#     574     hasattr(operation, "_call_has_training_arg")
#     575     and operation._call_has_training_arg
#     576     and training is not None
#     577 ):
#     578     kwargs["training"] = training
# --> 579 return operation(*args, **kwargs)
#
# File ~/Documents/GitHub/crypto-trader/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Documents/GitHub/crypto-trader/.venv/lib/python3.11/site-packages/keras/src/layers/layer.py:722, in Layer.__call__(self, *args, **kwargs)
#     715 # Used to avoid expensive `tree` operations in the most common case.
#     716 if (
#     717     kwargs
#     718     or len(args) != 1
#     719     or not backend.is_tensor(args[0])
#     720     or backend.standardize_dtype(args[0].dtype) != self.input_dtype
#     721 ) and self._convert_input_args:
# --> 722     args = tree.map_structure(maybe_convert, args)
#     723     kwargs = tree.map_structure(maybe_convert, kwargs)
#     725 ##########################################################
#     726 # 2. Enforce that only tensors can be passed positionally.
#
# File ~/Documents/GitHub/crypto-trader/.venv/lib/python3.11/site-packages/keras/src/utils/tree.py:239, in map_structure(func, *structures)
#     237 for other in structures[1:]:
#     238     assert_same_structure(structures[0], other, check_types=False)
# --> 239 return optree.tree_map(
#     240     func, *structures, none_is_leaf=True, namespace="keras"
#     241 )
#
# File ~/Documents/GitHub/crypto-trader/.venv/lib/python3.11/site-packages/optree/ops.py:594, in tree_map(func, tree, is_leaf, none_is_leaf, namespace, *rests)
#     592 leaves, treespec = _C.flatten(tree, is_leaf, none_is_leaf, namespace)
#     593 flat_args = [leaves] + [treespec.flatten_up_to(r) for r in rests]
# --> 594 return treespec.unflatten(map(func, *flat_args))
#
# File ~/Documents/GitHub/crypto-trader/.venv/lib/python3.11/site-packages/keras/src/layers/layer.py:711, in Layer.__call__.<locals>.maybe_convert(x)
#     710 def maybe_convert(x):
# --> 711     return self.dtype_policy.convert_input(
#     712         x, self.autocast, self.input_dtype
#     713     )
#
# File ~/Documents/GitHub/crypto-trader/.venv/lib/python3.11/site-packages/keras/src/dtype_policies/dtype_policy.py:137, in DTypePolicy.convert_input(self, x, autocast, dtype)
#     135 def convert_input(self, x, autocast, dtype):
#     136     dtype = backend.standardize_dtype(dtype)
# --> 137     if backend.is_tensor(x):
#     138         if (
#     139             autocast
#     140             and backend.is_float_dtype(x.dtype)
#     141             and x.dtype != dtype
#     142         ):
#     143             x = backend.cast(x, dtype=dtype)
#
# File ~/Documents/GitHub/crypto-trader/.venv/lib/python3.11/site-packages/keras/src/backend/tensorflow/core.py:138, in is_tensor(x)
#     137 def is_tensor(x):
# --> 138     return tf.is_tensor(x)
#
# File ~/Documents/GitHub/crypto-trader/.venv/lib/python3.11/site-packages/tensorflow/python/framework/tensor_util.py:1128, in is_tf_type(x)
#    1124 tf_type_classes = (internal.NativeObject, core.Tensor, IsTensorLike)
#    1127 # TODO(mdan): Deprecate in favor of more static-friendly types.
# -> 1128 @tf_export("is_tensor")
#    1129 def is_tf_type(x):  # pylint: disable=invalid-name
#    1130   """Checks whether `x` is a TF-native type that can be passed to many TF ops.
#    1131
#    1132   Use `is_tensor` to differentiate types that can ingested by TensorFlow ops
#    (...)
#    1154     `True` if `x` is a TensorFlow-native type.
#    1155   """
#    1156   return isinstance(x, tf_type_classes)
#
# KeyboardInterrupt:
